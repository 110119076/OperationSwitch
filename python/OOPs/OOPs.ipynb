# %% [markdown]
# ## OOPs concepts

# %%
class Employee:
    pass

# %%
emp1 = Employee()

# %%
emp1

# %%
emp2 = Employee()

# %%
emp2

# %%
emp1==emp2
# Out:
# False

# %%
type(emp1)
# Out:
# __main__.Employee

# %%
type(emp2)
# Out:
# __main__.Employee

# %% [markdown]
# ## Instance variables

# %%
emp1.first = "Benky"
emp1.last = "Bohr"
emp1.email = "benky.bohr@gmail.com"
emp1.pay = 5000

# %%
emp1.email
# Out:
# 'benky.bohr@gmail.com'

# %% [markdown]
# ### init Method

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'

# %%
emp1 = Employee("Benky", "bohr", 5000)

# %%
emp1.email
# Out:
# 'Benky.bohr@gmail.com'

# %% [markdown]
# ## Methods

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'

    def fullname(self):
        return f"{self.first} {self.last}"

# %%
emp1 = Employee("Benky", "Bohr", 5000)

# %%
emp1.fullname()
# Out:
# 'Benky Bohr'

# %%
emp1.fullname
# Out:
# <bound method Employee.fullname of <__main__.Employee object at 0x3cfca90>>

# %% [markdown]
# Using Class to call the method

# %%
Employee.fullname(emp1)
# Out:
# 'Benky Bohr'

# %% [markdown]
# Using Object to call the method

# %%
emp1.fullname()
# Out:
# 'Benky Bohr'

# %% [markdown]
# ## Class Variables

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'

    def fullname(self):
        return f"{self.first} {self.last}"

    def apply_raise(self):
        self.pay = int(self.pay * bonus_percent)

# %%
emp1 = Employee("Benky", "Bohr", 5000)

# %%
emp1.company
# Out:
# 'X AI'

# %%
emp1.pay
# Out:
# 5000

# %%
emp1.apply_raise()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 emp1.apply_raise()
#
# Cell In[32], line 14, in Employee.apply_raise(self)
#      13 def apply_raise(self):
# ---> 14     self.pay = int(self.pay * bonus_percent)
#
# NameError: name 'bonus_percent' is not defined

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'

    def fullname(self):
        return f"{self.first} {self.last}"

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

# %%
emp1 = Employee("Benky", "Bohr", 5000)
emp2 = Employee("Tony", "Stark", 3000)

# %%
emp1.pay
# Out:
# 5000

# %%
emp1.apply_raise()

# %%
emp1.pay
# Out:
# 5200

# %%
print(emp1.__dict__)
# Out:
# {'first': 'Benky', 'last': 'Bohr', 'pay': 5200, 'email': 'Benky.Bohr@gmail.com'}

# %% [markdown]
# There's no bonus_percent in emp1 object

# %%
print(Employee.__dict__)
# Out:
# {'__module__': '__main__', '__firstlineno__': 1, 'company': 'X AI', 'bonus_percent': 1.04, '__init__': <function Employee.__init__ at 0x3f1bab8>, 'fullname': <function Employee.fullname at 0x3f1bdc8>, 'apply_raise': <function Employee.apply_raise at 0x3f1d9c0>, '__static_attributes__': ('email', 'first', 'last', 'pay'), '__dict__': <attribute '__dict__' of 'Employee' objects>, '__weakref__': <attribute '__weakref__' of 'Employee' objects>, '__doc__': None}

# %% [markdown]
# There's bonus_percent available in the class

# %%
Employee.bonus_percent = 1.05

# %%
emp1.bonus_percent
# Out:
# 1.05

# %%
emp2.bonus_percent
# Out:
# 1.05

# %%
emp1.bonus_percent = 1.06

# %%
emp1.bonus_percent
# Out:
# 1.06

# %%
emp2.bonus_percent
# Out:
# 1.05

# %%
print(emp1.__dict__)
# Out:
# {'first': 'Benky', 'last': 'Bohr', 'pay': 5000, 'email': 'Benky.Bohr@gmail.com', 'bonus_percent': 1.06}

# %%
print(emp2.__dict__)
# Out:
# {'first': 'Tony', 'last': 'Stark', 'pay': 3000, 'email': 'Tony.Stark@gmail.com'}

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    num_of_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'
        Employee.num_of_emps += 1

    def fullname(self):
        return f"{self.first} {self.last}"

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

# %%
Employee.num_of_emps
# Out:
# 0

# %%
emp1 = Employee("Benky", "Bohr", 5000)
emp2 = Employee("Tony", "Stark", 3000)

# %%
Employee.num_of_emps
# Out:
# 2

# %% [markdown]
# ## Class Methods & Static Methods

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    num_of_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'
        Employee.num_of_emps += 1

    def fullname(self):
        return f"{self.first} {self.last}"

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

    @classmethod
    def set_raise_amt(cls, amount):
        cls.bonus_percent = amount

# %%
emp1 = Employee("Benky", "Bohr", 5000)
emp2 = Employee("Tony", "Stark", 3000)

# %%
emp1.apply_raise()
emp2.apply_raise()

# %%
emp1.pay
# Out:
# 5200

# %%
emp2.pay
# Out:
# 3120

# %%
Employee.set_raise_amt(1.05)

# %%
emp1.apply_raise()
emp2.apply_raise()

# %%
print(emp1.pay,emp2.pay)
# Out:
# 5250 3150

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    num_of_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'
        Employee.num_of_emps += 1

    def fullname(self):
        return f"{self.first} {self.last}"

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

    @classmethod
    def set_raise_amt(cls, amount):
        cls.bonus_percent = amount

    @classmethod
    def emp_from_str(cls,emp_str):
        first,last,pay = emp_str.split("-")
        return cls(first, last, pay)

# %%
emp1 = Employee.emp_from_str("Benky-Bohr-5000")

# %%
emp1.first
# Out:
# 'Benky'

# %%
emp1.email
# Out:
# 'Benky.Bohr@gmail.com'

# %%
import datetime
my_date = datetime.date(2016, 7, 11)

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    num_of_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'
        Employee.num_of_emps += 1

    def fullname(self):
        return f"{self.first} {self.last}"

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

    @classmethod
    def set_raise_amt(cls, amount):
        cls.bonus_percent = amount

    @classmethod
    def emp_from_str(cls,emp_str):
        first,last,pay = emp_str.split("-")
        return cls(first, last, pay)

    @staticmethod
    def is_workday(day):
        if day.weekday() == 5 or day.weekday()==6:
            return False
        return True

# %%
print(Employee.is_workday(my_date))
# Out:
# True

# %%
import datetime
my_date = datetime.date(2016, 7, 10)

# %%
print(Employee.is_workday(my_date))
# Out:
# False

# %% [markdown]
# ## Inheritance

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    num_of_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'
        Employee.num_of_emps += 1

    def fullname(self):
        return f"{self.first} {self.last}"

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

# %%
class Developer(Employee):
    bonus_percent = 1.10
    def __init__(self,first,last,pay,prog_lang):
        super().__init__(first,last,pay)
        self.prog_lang = prog_lang

# %%
class Manager(Employee):
    def __init__(self,first,last,pay,employees=None):
        super().__init__(first,last,pay)
        if employees is None:
            self.employees = []
        else:
            self.employees = employees

    def add_emp(self,emp):
        if emp not in self.employees:
            self.employees.append(emp)

    def remove_emp(self,emp):
        if emp in self.employees:
            self.employees.remove(emp)

    def print_emps(self):
        for emp in self.employees:
            print("---> "+emp.fullname())

# %%
dev1 = Developer('Corey', 'Schafer', 50000, 'Python')
dev2 = Developer('Test', 'Employee', 60000, 'Java')

# %%
dev1.prog_lang
# Out:
# 'Python'

# %%
dev1.apply_raise()

# %%
dev1.pay
# Out:
# 55000

# %%
mgr1 = Manager('Sue', 'Smith', 90000, [dev1])

# %%
mgr1.print_emps()
# Out:
# ---> Corey Schafer

# %%
mgr1.add_emp(dev2)

# %%
mgr1.print_emps()
# Out:
# ---> Corey Schafer
# ---> Test Employee

# %%
mgr1.remove_emp(dev1)

# %%
mgr1.print_emps()
# Out:
# ---> Test Employee

# %%
isinstance(mgr1,Manager)
# Out:
# True

# %%
isinstance(mgr1,Employee)
# Out:
# True

# %%
isinstance(dev1,Employee)
# Out:
# True

# %%
isinstance(dev1,Developer)
# Out:
# True

# %%
isinstance(mgr1,Developer)
# Out:
# False

# %%
issubclass(Developer,Employee)
# Out:
# True

# %%
issubclass(Manager,Employee)
# Out:
# True

# %%
issubclass(Manager,Developer)
# Out:
# False

# %% [markdown]
# ## Special Methods

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    num_of_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'
        Employee.num_of_emps += 1

    def fullname(self):
        return f"{self.first} {self.last}"

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

    def __repr__(self):
        return f"Employee({self.first},{self.last},{self.pay})"

# %%
emp1 = Employee("Benky", "Bohr", 5000)
emp2 = Employee("Tony", "Stark", 3000)

# %%
print(emp1)
# Out:
# Employee(Benky,Bohr,5000)

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    num_of_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'
        Employee.num_of_emps += 1

    def fullname(self):
        return f"{self.first} {self.last}"

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

    def __repr__(self):
        return f"Employee({self.first},{self.last},{self.pay})"

    def __str__(self):
        return f"{self.fullname()}"

# %%
emp1 = Employee("Benky", "Bohr", 5000)
emp2 = Employee("Tony", "Stark", 3000)

# %%
print(emp1)
# Out:
# Benky Bohr

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    num_of_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'
        Employee.num_of_emps += 1

    def fullname(self):
        return f"{self.first} {self.last}"

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

    def __repr__(self):
        return f"Employee({self.first},{self.last},{self.pay})"

    def __str__(self):
        return f"{self.fullname()}"

    def __add__(self,other):
        return self.pay + other.pay

# %%
emp1 = Employee("Benky", "Bohr", 5000)
emp2 = Employee("Tony", "Stark", 3000)
print(emp1+emp2)
# Out:
# 8000

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    num_of_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'
        Employee.num_of_emps += 1

    def fullname(self):
        return f"{self.first} {self.last}"

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

    def __repr__(self):
        return f"Employee({self.first},{self.last},{self.pay})"

    def __str__(self):
        return f"{self.fullname()}"

    def __add__(self,other):
        return self.pay + other.pay

    def __len__(self):
        return len(self.fullname())

# %%
emp1 = Employee("Benky", "Bohr", 5000)
len(emp1)
# Out:
# 10

# %% [markdown]
# ## Property Decorator

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    num_of_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first+"."+last + '@gmail.com'
        Employee.num_of_emps += 1

    def fullname(self):
        return f"{self.first} {self.last}"

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

    def __repr__(self):
        return f"Employee({self.first},{self.last},{self.pay})"

    def __str__(self):
        return f"{self.fullname()}"

    def __add__(self,other):
        return self.pay + other.pay

    def __len__(self):
        return len(self.fullname())

# %%
emp1 = Employee("Benky", "Bohr", 5000)

# %%
emp1.fullname()
# Out:
# 'Benky Bohr'

# %%
emp1.email
# Out:
# 'Benky.Bohr@gmail.com'

# %%
emp1.last = "Stark"

# %%
emp1.fullname()
# Out:
# 'Benky Stark'

# %%
emp1.email
# Out:
# 'Benky.Bohr@gmail.com'

# %%
emp1.fullname = "Benky Potter"

# %%
emp1.last
# Out:
# 'Stark'

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    num_of_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        Employee.num_of_emps += 1

    @property
    def email(self):
        return f"{self.first}.{self.last}@gmail.com"

    @property
    def fullname(self):
        return f"{self.first} {self.last}"

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

    def __repr__(self):
        return f"Employee({self.first},{self.last},{self.pay})"

    def __str__(self):
        return f"{self.fullname()}"

    def __add__(self,other):
        return self.pay + other.pay

    def __len__(self):
        return len(self.fullname())

# %%
emp1 = Employee("Benky", "Bohr", 5000)

# %%
emp1.email
# Out:
# 'Benky.Bohr@gmail.com'

# %%
emp1.last="Potter"

# %%
emp1.email
# Out:
# 'Benky.Potter@gmail.com'

# %%
emp1.fullname()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 emp1.fullname()
#
# TypeError: 'str' object is not callable

# %%
emp1.fullname
# Out:
# 'Benky Potter'

# %%
emp1.fullname = "Benky Stark"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 emp1.fullname = "Benky Stark"
#
# AttributeError: property 'fullname' of 'Employee' object has no setter

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    num_of_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        Employee.num_of_emps += 1

    @property
    def email(self):
        return f"{self.first}.{self.last}@gmail.com"

    @property
    def fullname(self):
        return f"{self.first} {self.last}"

    @fullname.setter
    def fullname(self,name):
        first,last=name.split()
        self.first=first
        self.last=last

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

    def __repr__(self):
        return f"Employee({self.first},{self.last},{self.pay})"

    def __str__(self):
        return f"{self.fullname()}"

    def __add__(self,other):
        return self.pay + other.pay

    def __len__(self):
        return len(self.fullname())

# %%
emp1 = Employee("Benky", "Bohr", 5000)

# %%
emp1.email
# Out:
# 'Benky.Bohr@gmail.com'

# %%
emp1.last = "Potter"

# %%
emp1.email
# Out:
# 'Benky.Potter@gmail.com'

# %%
emp1.fullname
# Out:
# 'Benky Potter'

# %%
emp1.fullname = "Benky Wick"

# %%
emp1.last
# Out:
# 'Wick'

# %%
emp1.email
# Out:
# 'Benky.Wick@gmail.com'

# %%
del emp1.fullname
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 del emp1.fullname
#
# AttributeError: property 'fullname' of 'Employee' object has no deleter

# %%
class Employee:
    company = "X AI"
    bonus_percent = 1.04
    num_of_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        Employee.num_of_emps += 1

    @property
    def email(self):
        return f"{self.first}.{self.last}@gmail.com"

    @property
    def fullname(self):
        if self.first and self.last:
            return f"{self.first} {self.last}"

    @fullname.setter
    def fullname(self,name):
        first,last=name.split()
        self.first=first
        self.last=last

    @fullname.deleter
    def fullname(self):
        self.first = None
        self.last = None
        print("Deleted fullname")

    def apply_raise(self):
        self.pay = int(self.pay * self.bonus_percent)

    def __repr__(self):
        return f"Employee({self.first},{self.last},{self.pay})"

    def __str__(self):
        return f"{self.fullname}"

    def __add__(self,other):
        return self.pay + other.pay

    def __len__(self):
        return len(self.fullname())

# %%
emp1 = Employee("Benky", "Bohr", 5000)

# %%
print(emp1.fullname,emp1.email)
# Out:
# Benky Bohr Benky.Bohr@gmail.com

# %%
emp1.last = "Potter"

# %%
print(emp1.fullname,emp1.email)
# Out:
# Benky Potter Benky.Potter@gmail.com

# %%
emp1.fullname="Benky Wick"

# %%
print(emp1.fullname,emp1.email)
# Out:
# Benky Wick Benky.Wick@gmail.com

# %%
del emp1.fullname
# Out:
# Deleted fullname

# %%
emp1.first

# %%
emp1.last

# %%
print(emp1)
# Out:
# None
